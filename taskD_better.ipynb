# %%
import pandas as pd

# %%
titanic = pd.read_excel('titanic.xls')

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
titanic.drop(columns=['sibsp', 'fare', 'cabin'])
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic = titanic.drop(columns=['sibsp', 'fare', 'cabin'])

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  parch  ticket embarked boat   body  \
# 0  29.0000      0   24160        S    2    NaN
# 1   0.9167      2  113781        S   11    NaN
# 2   2.0000      2  113781        S  NaN    NaN
# 3  30.0000      2  113781        S  NaN  135.0
# 4  25.0000      2  113781        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic = titanic.drop(['embarked', 'body', 'home.dest'], axis=1)
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  parch  ticket boat
# 0  29.0000      0   24160    2
# 1   0.9167      2  113781   11
# 2   2.0000      2  113781  NaN
# 3  30.0000      2  113781  NaN
# 4  25.0000      2  113781  NaN

# %%
titanic = titanic.drop(['boat', 'ticket', 'boat'], axis=1)
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  parch
# 0  29.0000      0
# 1   0.9167      2
# 2   2.0000      2
# 3  30.0000      2
# 4  25.0000      2

# %%
titanic.mean()
# Out:
# pclass       2.294882
# survived     0.381971
# age         29.881135
# parch        0.385027
# dtype: float64

# %%
titanic = titanic.drop(columns=['parch'])

# %%
titanic.groupby(['sex', 'pclass']).mean()
# Out:
#                survived        age
# sex    pclass
# female 1       0.965278  37.037594
#        2       0.886792  27.499191
#        3       0.490741  22.185307
# male   1       0.340782  41.029250
#        2       0.146199  30.815401
#        3       0.152130  25.962273

# %%
titanic.groupby(['pclass', 'sex']).mean()
# Out:
#                survived        age
# pclass sex
# 1      female  0.965278  37.037594
#        male    0.340782  41.029250
# 2      female  0.886792  27.499191
#        male    0.146199  30.815401
# 3      female  0.490741  22.185307
#        male    0.152130  25.962273

# %%
titanic.groupby(['survived', 'sex']).mean()
# Out:
#                    pclass        age
# survived sex
# 0        female  2.826772  25.255208
#          male    2.439883  31.516412
# 1        female  1.902655  29.815354
#          male    2.086957  26.977778

# %%
titanic.groupby(['survived', 'pclass', 'sex']).mean()
# Out:
#                               age
# survived pclass sex
# 0        1      female  35.200000
#                 male    43.658163
#          2      female  34.090909
#                 male    33.092593
#          3      female  23.418750
#                 male    26.679598
# 1        1      female  37.109375
#                 male    36.168240
#          2      female  26.711051
#                 male    17.449274
#          3      female  20.814815
#                 male    22.436441

# %%
titanic[titanic.age > 20].mean()
# Out:
# pclass       2.095238
# survived     0.392231
# age         35.194862
# dtype: float64

# %%
titanic[titanic.age > 20].groupby(['pclass', 'sex']).mean()
# Out:
#                survived        age
# pclass sex
# 1      female  0.965812  39.880342
#        male    0.333333  43.053191
# 2      female  0.868421  33.059211
#        male    0.076923  34.876923
# 3      female  0.441860  30.401163
#        male    0.157258  31.000000
